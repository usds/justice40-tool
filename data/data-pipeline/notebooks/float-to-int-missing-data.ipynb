# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([np.arange(1,4)],index=['a','b','c'],
columns=["X","Y","Z"]) 
df = df.reindex(index=['a','b','c','d'])

# %%
df
# Out:
#      X    Y    Z
# a  1.0  2.0  3.0
# b  1.0  2.0  3.0
# c  1.0  2.0  3.0
# d  NaN  NaN  NaN

# %%
df["X"] = pd.Series(df["X"], dtype="Int64")
df
# Out:
#       X    Y    Z
# a     1  2.0  3.0
# b     1  2.0  3.0
# c     1  2.0  3.0
# d  <NA>  NaN  NaN

# %%
df["X"]
# Out:
# a       1
# b       1
# c       1
# d    <NA>
# Name: X, dtype: Int64

# %% [markdown]
# As a follow-up to the above here are contrasts in the subset of tracts where Score L's approach - using  housing burden relative to all owned and rental properties - is considered burdened. However, these tracts not considered burdened by the methodology employed in CalEnviroScreen (n = 2741 tracts).

# %%
bar_styled_score_l
# Out:
# <style  type="text/css" >
# #T_7116eda8_67ee_11ec_a530_acde48001122row0_col0,#T_7116eda8_67ee_11ec_a530_acde48001122row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 45.9%, transparent 45.9%);
#         }#T_7116eda8_67ee_11ec_a530_acde48001122row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.1%, transparent 22.1%);
#         }#T_7116eda8_67ee_11ec_a530_acde48001122row0_col2,#T_7116eda8_67ee_11ec_a530_acde48001122row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 59.0%, transparent 59.0%);
#         }#T_7116eda8_67ee_11ec_a530_acde48001122row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 4.8%, transparent 4.8%);
# ...

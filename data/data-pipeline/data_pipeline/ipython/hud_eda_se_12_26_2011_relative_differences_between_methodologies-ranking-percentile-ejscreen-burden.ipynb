# %% [markdown]
# ###### Summary statistics for census tracts that are considered burdened using the CalEnviroScreen ranked percentile, but are not included in Score L's housing burden (n = 2272)

# %%
bar_styled_ej_screen
# Out:
# <style  type="text/css" >
# #T_549e822e_67f2_11ec_afe7_acde48001122row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 52.4%, transparent 52.4%);
#         }#T_549e822e_67f2_11ec_afe7_acde48001122row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 45.5%, transparent 45.5%);
#         }#T_549e822e_67f2_11ec_afe7_acde48001122row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 18.2%, transparent 18.2%);
#         }#T_549e822e_67f2_11ec_afe7_acde48001122row0_col3,#T_549e822e_67f2_11ec_afe7_acde48001122row40_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.7%, transparent 7.7%);
# ...
